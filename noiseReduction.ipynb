# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_noisy1= cv2.imread('a.jpg',0)
#obtain no of rows and columnsnof image
m,n = img_noisy1.shape
print(m,n)
plt.imshow(img_noisy1)
plt.set_cmap('gray')
# Out:
# 721 721

# %%
mask= np.ones([3,3], dtype= int)
print(mask/9)
# Out:
# [[0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]]

# %%
img_new= np.zeros([3,3], dtype= int)
print(img_new)
# Out:
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]

# %%
# Apply the convolution
filtered_image = signal.convolve2d(img_noisy1, mask, mode="same")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8743/3738532063.py in <module>
#       1 # Apply the convolution
# ----> 2 filtered_image = signal.convolve2d(img_noisy1, mask, mode="same")
#
# NameError: name 'signal' is not defined

# %%
def smooth(img,size):
    mask= np.ones
    for k in range (0,256):
        for i in range[1:m-1]:             #traverse each pixel in the image 
                for j in range[1:n-1]:
                    
                    #x=k[0]*f(i-1,j+1)+k[1]f(i,j+1)
